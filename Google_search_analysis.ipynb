# %%
import pandas as pd

# %%
# !pip install pytrends
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Created wheel for pytrends: filename=pytrends-4.8.0-py3-none-any.whl size=16127 sha256=7773cc5df3dece6a73071d5eec2447c6a67be542989dcb619985700ef8ea2c94
#   Stored in directory: /root/.cache/pip/wheels/e8/78/c8/18d4f4804753e14416809b365773220c48b41fe5387f2bb6b9
# Successfully built pytrends
# ...

# %%
from pytrends.request import TrendReq

# %%
from matplotlib import pyplot as plt

# %%
trends=TrendReq()

# %%
print(trends)

# %%
print(trends.build_payload(kw_list=["web development"]))
# Out:
# None

# %%
data=trends.interest_by_region()
print(data)
# Out:
#                 web development
# geoName
# Afghanistan                   0
# Albania                       0
# Algeria                      14
# American Samoa                0
# Andorra                       0
# ...                         ...
# Western Sahara                0
# Yemen                         0
# Zambia                        0
# Zimbabwe                     71
# Åland Islands                 0
#
# [250 rows x 1 columns]

# %%
data=data.sort_values("web development" , ascending=False)
#print(data)
data=data.head(10)
print(data)
# Out:
#             web development
# geoName
# Pakistan                100
# Bangladesh               83
# Ethiopia                 78
# St. Helena               71
# Zimbabwe                 71
# Nepal                    67
# Nigeria                  63
# Sri Lanka                62
# Laos                     60
# Kenya                    56

# %%
data.reset_index().plot(x="geoName" ,y="web development",figsize=(15,5),kind="bar")
plt.style.use('fivethirtyeight')
plt.show()

# %%
data = TrendReq(hl='en-US', tz=360)
print(data)

# %%
print(data.build_payload(kw_list=['web development']))
# Out:
# None

# %%
data = data.interest_over_time()
print(data)
# Out:
#             web development  isPartial
# date
# 2017-12-31               49      False
# 2018-01-07               55      False
# 2018-01-14               53      False
# 2018-01-21               48      False
# 2018-01-28               54      False
# ...                     ...        ...
# 2022-11-20               84      False
# 2022-11-27               78      False
# 2022-12-04               81      False
# 2022-12-11               91      False
# 2022-12-18               85       True
#
# [260 rows x 2 columns]

# %%
fig, ax = plt.subplots(figsize=(15, 5))
data['web development'].plot()
plt.style.use('fivethirtyeight')
plt.title('Total Google Searches for web development', 
          fontweight='bold')
plt.xlabel('Year')
plt.ylabel('Total Count')
plt.show()
